# %% [markdown]
# # "Big ideas" in programming
# - "logical thinking"
# - formal language and syntax
#
# vad består ett program av?
# - variables and constants
# - parameters
# - flow control
# - function, process, method
# - algorithm -
#     - exempel:
#     - Donald Knut, "The art of computer programming"
#     -     algorithms
#     -     linear regression
#     -     support vector machines
#     -     long-short-term memory
#     -     neat
#
# - data structures
# - composition / decomposition
# - reusability (DRY - Don't repeat yourself)

# %% [markdown]
# # kvadratisk ekvation
#
# $ax^2 + bx^2 + c = 0$
#
# $ax^2 + 2x^2 + 1 = 0$
#
# # PQ formel
# $ x^2 + px + q = 0$
#
# $x = -\frac{p}{2} \pm \sqrt{(\frac{p}{2})^2 - q}$

# %%
import numpy as np

q_term = [1, 2, 1]
matris_exempel = [[1, 1, 1],
                  [2, 2, 2],
                  [3, 3, 3]]

def quadratic_solver(coeff): # abc / kvadratisk formel
    a, b, c = coeff
    x1 = np.divide( - b + np.sqrt(np.square(b) - 4*a*c) , 2*a)
    x0 = np.divide( - b - np.sqrt(np.square(b) - 4*a*c) , 2*a)
    return x0, x1



print(quadratic_solver(q_term))
# Out:
# (-1.0, -1.0)

# %%
# pasta konsumption
# year 0 = 1960

for year in range(1000):
    pasta_consumption = .791 * np.exp(.0526*year)
    if pasta_consumption > 15:
        print(f"Year {year+1960} is the first year that pasta consumption reaches 15kg")
        break
# Out:
# Year 2016 is the first year that pasta consumption reaches 15kg

# %%
import matplotlib.pyplot as plt

pasta_per_year = []

for year in range(60):
    pasta_consumption = .791 * np.exp(.0526*year)
    pasta_per_year.append(pasta_consumption)

plt.plot(range(1960,2020),pasta_per_year)
plt.xlabel("year")
plt.ylabel("pasta consumption in kg")
plt.title("pasta consumption in kg per person per year from 1960")
plt.grid(True)
