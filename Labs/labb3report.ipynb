# %% [markdown]
# # Rapport Labb 3, Linjär klassifiering

# %% [markdown]
# Detta är en kort analysering av skillnader i klassifikation beroende på vilken lutning och skärningspunkt vår linjära separationslinje har.
#
# nedan följer en

# %%
import matplotlib.pyplot as plt
import labb3 as l3


axes = plt.axes()

l3.plot_classified_points(axes=axes, color="magenta", label="k = -0.5, m = 0")

l3.plot_classified_points(k=800, m = -120, axes=axes, color="blue", label="k = 800, m = -120")

l3.plot_classified_points(k=-2, m = .16, axes=axes, color="red",label="k = -2, m=0.16" )

l3.plot_classified_points(k=-.489, axes=axes, color="green", label="k = -0.489, m = -120")
plt.grid()
plt.legend(loc="upper right")
plt.show()
# Out:
# Data för linje med lutning: -0.5, skärningspunkt 0
# Antal punkter till höger om linjen: 301
# Antal punkter till vänster om linjen: 299
# Data för linje med lutning: 800, skärningspunkt -120
# Antal punkter till höger om linjen: 302
# Antal punkter till vänster om linjen: 298
# Data för linje med lutning: -2, skärningspunkt 0.16
# Antal punkter till höger om linjen: 301
# Antal punkter till vänster om linjen: 299
# Data för linje med lutning: -0.489, skärningspunkt 0
# Antal punkter till höger om linjen: 301
# Antal punkter till vänster om linjen: 299
