# %%
import matplotlib.pyplot as plt
import labb3 as l3


axes = plt.axes()
print("differences")
l3.plot_classified_points(k=800, m = -120, axes=axes, color="blue", label="k = 800, m = -120")

print("differences")
l3.plot_classified_points(k=-2, m = .16, axes=axes, color="seagreen",label="k = -2, m=0.16" )
print("differences")
l3.plot_classified_points(k=-0.489, axes=axes, color="blue", label="k = -0.489, m = -120")
print("differences")
l3.plot_classified_points(axes=axes, color="magenta")


plt.show()
# Out:
# differences
# 302
# 298
# differences
# 301
# 299
# differences
# 301
# 299
# differences
# 301
# 299
